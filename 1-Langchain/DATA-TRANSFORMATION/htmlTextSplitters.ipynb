# %%
from langchain_text_splitters import HTMLHeaderTextSplitter

html_string = """
<!DOCTYPE html>
<html>
<head>
  <title>My Simple Page</title>
</head>
<body>
  <h1>Welcome to My Website</h1>
  <h2>This is a simple HTML page.</h2>
  <h3>This is a simple HTML page yes .</h3>
  <p>HTML stands for HyperText Markup Language.</p>
  <button onclick="alert('Hello!')">Click Me</button>
  <hr>
  <p>Made with ❤️ by Shravya</p>
</body>
</html>
"""
headers_to_split_on = [
    ('h1', 'Header 1'),
    ('h2', 'Header 2'),
    ('h3', 'Header 3')
]

html_splitter =HTMLHeaderTextSplitter(headers_to_split_on = headers_to_split_on)
html_header_splits = html_splitter.split_text(html_string)

html_header_splits
# Out:
# [Document(metadata={'Header 1': 'Welcome to My Website'}, page_content='Welcome to My Website'),
#  Document(metadata={'Header 1': 'Welcome to My Website', 'Header 2': 'This is a simple HTML page.'}, page_content='This is a simple HTML page.'),
#  Document(metadata={'Header 1': 'Welcome to My Website', 'Header 2': 'This is a simple HTML page.', 'Header 3': 'This is a simple HTML page yes .'}, page_content='This is a simple HTML page yes .'),
#  Document(metadata={'Header 1': 'Welcome to My Website', 'Header 2': 'This is a simple HTML page.', 'Header 3': 'This is a simple HTML page yes .'}, page_content='HTML stands for HyperText Markup Language.  \nClick Me  \nMade with ❤️ by Shravya')]
