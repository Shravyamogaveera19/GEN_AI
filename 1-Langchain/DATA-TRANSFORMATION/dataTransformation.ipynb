# %%
##Loading PDF
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('MINI_PROJECT_REPORT.pdf')
docs = loader.load()
docs
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-07-18T13:10:51+05:30', 'author': 'PC', 'moddate': '2025-07-18T13:10:51+05:30', 'source': 'MINI_PROJECT_REPORT.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}, page_content='Mini Project Report Guidelines  \n \n1. Project report should be typed only on one side of the paper with 1.5-line spacing on A4  \nsize sheet (210 x 297 mm). The margins should be: Left - 1.25", Right - 1", Top and  \nBottom - 0.75".   \n2. The font style for the different sections:  \n- Font type: Times New Roman   \n- Font Size: chapter headings 16, main heading 14, sub-heading 12, body of the text  \n12.   \n3. The total number of reports to be prepared is   \n∙ One copy to the Project team. \n∙ One copy to the concerned guide.  \n4. Before taking the final printout, the approval of the concerned guide is mandatory and \nsuggested corrections, if any, must be incorporated.  \n5. The organizat
# ...

# %%
# !where python
# Out:
# c:\Users\shrav\anaconda3\python.exe
# C:\Users\shrav\AppData\Local\Programs\Python\Python312\python.exe
# C:\Users\shrav\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size = 500, chunk_overlap= 50)
final_documents = text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-07-18T13:10:51+05:30', 'author': 'PC', 'moddate': '2025-07-18T13:10:51+05:30', 'source': '../DATA-INGESTION/MINI_PROJECT_REPORT.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}, page_content='Mini Project Report Guidelines  \n \n1. Project report should be typed only on one side of the paper with 1.5-line spacing on A4  \nsize sheet (210 x 297 mm). The margins should be: Left - 1.25", Right - 1", Top and  \nBottom - 0.75".   \n2. The font style for the different sections:  \n- Font type: Times New Roman   \n- Font Size: chapter headings 16, main heading 14, sub-heading 12, body of the text  \n12.   \n3. The total number of reports to be prepared is   \n∙ One copy to the Project team.'),
# ...

# %%
print(final_documents[0])
# Out:
# page_content='Mini Project Report Guidelines
#
# 1. Project report should be typed only on one side of the paper with 1.5-line spacing on A4
# size sheet (210 x 297 mm). The margins should be: Left - 1.25", Right - 1", Top and
# Bottom - 0.75".
# 2. The font style for the different sections:
# - Font type: Times New Roman
# - Font Size: chapter headings 16, main heading 14, sub-heading 12, body of the text
# 12.
# 3. The total number of reports to be prepared is
# ∙ One copy to the Project team.' metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2025-07-18T13:10:51+05:30', 'author': 'PC', 'moddate': '2025-07-18T13:10:51+05:30', 'source': '../DATA-INGESTION/MINI_PROJECT_REPORT.pdf', 'total_pages': 24, 'page': 0, 'page_label': '1'}

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('speech.txt')
docs = loader.load()

speech = ""
with open("speech.txt") as f:
    speech = f.read()

textSplitter = RecursiveCharacterTextSplitter(chunk_size=20,chunk_overlap = 10)
text = textSplitter.create_documents([speech])
print(text[0])
print(text[1])
# Out:
# page_content='Keep going even when'
# page_content='even when it’s'

# %%
##Using Character Text Splitters
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(separator="\n\n", chunk_size=100, chunk_overlap = 20)
text_splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Keep going even when it’s tough,\nThe climb is hard, the view is enough.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Dream big, work smart, stay true,\nThe best version waits inside you.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Keep going even when it’s tough,\nThe climb is hard, the view is enough.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Dream big, work smart, stay true,\nThe best version waits inside you.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Keep going even when it’s tough,\nThe climb is hard, the view is enough.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Dream big, work smart, stay true,\nThe best version waits inside you.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Keep going even when it’s tough,\nThe climb is hard, the view is enough.'),
# ...

# %%
##Using Character Text Splitters
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=100, chunk_overlap = 10)
text_splitter.split_documents(docs)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Keep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enough.\nDream big, work smart, stay true,\nThe best version waits inside you.\nKeep going even when it’s tough,\nThe climb is hard, the view is enou
# ...
